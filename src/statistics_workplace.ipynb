# %%
db = "workplace_2013"
name = "/home/mehdi/Nextcloud/experiments/betweenness_discrete/shortest/"+db+".csv"
directed = False
stri = ["non-strict","strict"]
be = ["bet", "bet_exact"]
if directed:
    path = name+"_directed_exp"
else:
    path = name+"_undirected_exp"
path = path + "_boost/"
cost_type = [["shortest","passive"], ["shortest","active"]]
app = [-1]

# %%
f = open(path+"info_-1.txt", "r")
i = 0
for x in f:
    x = x[:-1]
    res = x.split(" ")
    if i == 0:
        n = int(res[-1])
    if i == 1:
        T = int(res[-1])
    i = i + 1
print(n,T)
# Out:
# 92 7104

# %%
res = dict()
res_bet = dict()
res_sum_node = dict()
res_sum_time = dict()

# res_sum_node = [0 for i in range(n)]
# res_sum_time = [0 for i in range(T)]

for b in be:
    for st in stri:
        for co in cost_type:
            for ap in app:
                f = open(path+b+"_"+st+"_"+co[0]+"_"+co[1]+"_"+str(ap)+".txt", "r")
                if ap not in res:
                    res[ap] = dict()
                if ap not in res_bet:
                    res_bet[ap] = dict()
                if ap not in res_sum_node:
                    res_sum_node[ap] = dict()
                if ap not in res_sum_time:
                    res_sum_time[ap] = dict()
                    
                if st not in res[ap]:
                    res[ap][st] = dict()
                if st not in res_bet[ap]:
                    res_bet[ap][st] = dict()
                if st not in res_sum_node[ap]:
                    res_sum_node[ap][st] = dict()
                if st not in res_sum_time[ap]:
                    res_sum_time[ap][st] = dict()
                    
                if b not in res_bet[ap][st]:
                    res_bet[ap][st][b] = dict()
                res_bet[ap][st][b][co[0]+"_"+co[1]] = []
                
                if b not in res[ap][st]:
                    res[ap][st][b] = dict()
                    
                if b not in res_sum_node[ap][st]:
                    res_sum_node[ap][st][b] = dict()
                if b not in res_sum_time[ap][st]:
                    res_sum_time[ap][st][b] = dict()

                if co[1] not in res[ap][st][b]:
                    res[ap][st][b][co[1]] = dict()
                if co[1] not in res_sum_node[ap][st][b]:
                    res_sum_node[ap][st][b][co[1]] = dict()
                if co[1] not in res_sum_time[ap][st][b]:
                    res_sum_time[ap][st][b][co[1]] = dict()

                res[ap][st][b][co[1]][co[0]] = []
                
                res_sum_time[ap][st][b][co[1]][co[0]] = [0 for i in range(T)]
                res_sum_node[ap][st][b][co[1]][co[0]] = [0 for i in range(n)]

                
                
                i = 0
                for x in f:
                    res_sum_node[ap][st][b][co[1]][co[0]][i//T] +=  float(x)
                    res_sum_time[ap][st][b][co[1]][co[0]][i%T] += float(x)
                    res[ap][st][b][co[1]][co[0]].append(float(x))
                    res_bet[ap][st][b][co[0]+"_"+co[1]].append(float(x))
                    i += 1

# %%
f = open(path+"staticBet.txt", "r")
stat = []
i = 0
for x in f:
    x = x[:-1]
    stat.append([float(x),i])
    i = i + 1

# %%
stat[:5]
# Out:
# [[29.2791, 0], [6.74757, 1], [174.187, 2], [1.56315, 3], [50.738, 4]]

# %%
f = open(path+"nodesIds.txt", "r")
id_to_node = dict()
for x in f:
    x = x[:-1]
    res = x.split(" ")
    id_to_node[res[0]] = res[1]

# %%
id_to_node
# Out:
# {'0': '492',
#  '1': '938',
#  '2': '267',
#  '3': '272',
#  '4': '181',
#  '5': '826',
#  '6': '79',
#  '7': '150',
#  '8': '196',
#  '9': '21',
#  '10': '205',
#  '11': '448',
#  '12': '765',
#  '13': '39',
#  '14': '253',
#  '15': '80',
#  '16': '123',
#  '17': '845',
#  '18': '118',
#  '19': '311',
#  '20': '95',
#  '21': '771',
#  '22': '153',
#  '23': '164',
#  '24': '179',
#  '25': '481',
#  '26': '122',
#  '27': '120',
#  '28': '819',
#  '29': '431',
#  '30': '778',
#  '31': '271',
#  '32': '601',
#  '33': '15',
#  '34': '56',
#  '35': '194',
#  '36': '786',
#  '37': '603',
#  '38': '496',
#  '39': '275',
#  '40': '222',
#  '41': '50',
#  '42': '172',
#  '43': '29',
#  '44': '223',
#  '45': '116',
#  '46': '285',
#  '47': '762',
#  '48': '63',
#  '49': '939',
#  '50': '335',
#  '51': '105',
#  '52': '113',
#  '53': '513',
#  '54': '119',
#  '55': '154',
#  '56': '494',
#  '57': '48',
#  '58': '209',
#  '59': '17',
#  '60': '66',
#  '61': '102',
#  '62': '134',
#  '63': '240',
#  '64': '242',
#  '65': '804',
#  '66': '511',
#  '67': '875',
#  '68': '184',
#  '69': '499',
#  '70': '268',
#  '71': '185',
#  '72': '533',
#  '73': '987',
#  '74': '210',
#  '75': '35',
#  '76': '131',
#  '77': '211',
#  '78': '751',
#  '79': '265',
#  '80': '784',
#  '81': '273',
#  '82': '662',
#  '83': '709',
#  '84': '101',
#  '85': '779',
#  '86': '132',
#  '87': '255',
#  '88': '213',
#  '89': '791',
#  '90': '743',
#  '91': '87'}

# %%
path_meta = "/home/mehdi/code/code_temporal_betweenness_/src/examples/"
f = open(path_meta+"metadata_"+db+".txt", "r")
node_to_cat = dict()
for x in f:
    x = x[:-1]
    res = x.split("\t")
    node_to_cat[res[0]] = res[1]

# %%
node_to_cat
# Out:
# {'35': 'DISQ',
#  '184': 'DISQ',
#  '751': 'DISQ',
#  '255': 'DISQ',
#  '131': 'DISQ',
#  '273': 'DISQ',
#  '743': 'DISQ',
#  '210': 'DISQ',
#  '826': 'DISQ',
#  '265': 'DISQ',
#  '845': 'DISQ',
#  '185': 'DISQ',
#  '268': 'DISQ',
#  '778': 'DISQ',
#  '253': 'DISQ',
#  '172': 'DSE',
#  '513': 'DSE',
#  '29': 'DSE',
#  '272': 'DSE',
#  '79': 'DSE',
#  '181': 'DSE',
#  '196': 'DSE',
#  '56': 'DSE',
#  '164': 'DSE',
#  '242': 'DSE',
#  '223': 'DSE',
#  '120': 'DSE',
#  '311': 'DSE',
#  '496': 'DSE',
#  '132': 'DSE',
#  '819': 'DSE',
#  '603': 'DSE',
#  '267': 'DSE',
#  '222': 'DSE',
#  '205': 'DSE',
#  '662': 'DSE',
#  '113': 'DSE',
#  '123': 'DSE',
#  '39': 'DSE',
#  '779': 'DSE',
#  '95': 'DSE',
#  '791': 'DSE',
#  '194': 'DSE',
#  '786': 'DSE',
#  '15': 'DSE',
#  '494': 'DSE',
#  '765': 'DSE',
#  '987': 'DSE',
#  '939': 'DSE',
#  '87': 'SFLE',
#  '213': 'SFLE',
#  '211': 'SFLE',
#  '116': 'SFLE',
#  '209': 'DMCT',
#  '938': 'DMCT',
#  '875': 'DMCT',
#  '179': 'DMCT',
#  '80': 'DMCT',
#  '21': 'DMCT',
#  '101': 'DMCT',
#  '48': 'DMCT',
#  '511': 'DMCT',
#  '102': 'DMCT',
#  '762': 'DMCT',
#  '66': 'DMCT',
#  '134': 'DMCT',
#  '17': 'DMCT',
#  '119': 'DMCT',
#  '771': 'DMCT',
#  '784': 'DMCT',
#  '105': 'DMCT',
#  '118': 'DMCT',
#  '431': 'DMCT',
#  '285': 'DMCT',
#  '240': 'DMCT',
#  '804': 'DMCT',
#  '335': 'DMCT',
#  '50': 'DMCT',
#  '275': 'DMCT',
#  '709': 'SRH',
#  '533': 'SRH',
#  '448': 'SRH',
#  '481': 'SRH',
#  '154': 'SRH',
#  '122': 'SRH',
#  '492': 'SRH',
#  '153': 'SRH',
#  '601': 'SRH',
#  '271': 'SRH',
#  '63': 'SRH',
#  '150': 'SRH',
#  '499': 'SRH'}

# %%
max_elem_pas = [ [res_sum_node[-1]["non-strict"]["bet_exact"]["passive"]["shortest"][i],i] for i in range(0,len(res_sum_node[-1]["non-strict"]["bet_exact"]["passive"]["shortest"])) ]
max_elem_pas.sort(reverse=True)

# %%
max_elem_act = [ [res_sum_node[-1]["non-strict"]["bet_exact"]["active"]["shortest"][i],i] for i in range(0,len(res_sum_node[-1]["non-strict"]["bet_exact"]["passive"]["shortest"])) ]
max_elem_act.sort(reverse=True)

# %%
max_elem_stat = stat
max_elem_stat.sort(reverse=True)

# %%
for x,y,z in zip(max_elem_act,max_elem_pas,max_elem_stat):
    print(node_to_cat[(id_to_node[str(x[1])])],x[1],"  ",node_to_cat[(id_to_node[str(y[1])])],y[1],"  ",node_to_cat[(id_to_node[str(z[1])])],z[1])
# Out:
# DMCT 65    DMCT 65    DMCT 65
# DSE 19    DSE 19    DSE 19
# DSE 16    SRH 48    SRH 48
# SRH 48    SRH 7    DMCT 62
# SRH 7    DSE 16    DSE 16
# DMCT 41    DISQ 79    DMCT 15
# DSE 27    DSE 20    DISQ 5
# DSE 20    DMCT 62    DSE 20
# DSE 44    DSE 13    DSE 44
# SRH 22    DSE 44    DISQ 79
# DISQ 79    DISQ 5    DSE 34
# DSE 35    DMCT 15    DSE 13
# DMCT 67    DMCT 54    DMCT 54
# DSE 52    DSE 35    DSE 43
# DMCT 54    DMCT 67    DSE 2
# DISQ 30    DSE 34    DMCT 67
# DSE 13    DSE 2    SRH 7
# DISQ 68    DSE 40    DSE 40
# SRH 31    DISQ 30    DISQ 87
# DSE 40    DMCT 41    DMCT 61
# DMCT 84    DSE 27    DSE 82
# DSE 2    DSE 6    DISQ 68
# DSE 12    DISQ 87    DSE 38
# DMCT 62    DISQ 68    DISQ 76
# SRH 72    DSE 43    DISQ 30
# DSE 86    DISQ 76    DSE 6
# DISQ 14    SRH 22    DMCT 58
# DSE 34    DISQ 14    SRH 22
# DSE 6    DSE 82    SFLE 45
# SFLE 77    DSE 37    DSE 35
# DSE 56    SRH 31    DSE 8
# DMCT 51    DMCT 61    DMCT 9
# DMCT 15    SFLE 45    DISQ 14
# DISQ 87    DMCT 29    DMCT 29
# DSE 38    SFLE 77    DSE 27
# SRH 25    DSE 38    SRH 55
# DISQ 70    DSE 86    SRH 31
# SRH 26    DMCT 58    DISQ 78
# DSE 43    DSE 10    SRH 11
# SRH 83    DISQ 78    SFLE 77
# DISQ 76    DSE 23    DMCT 39
# DISQ 78    DSE 52    DSE 42
# SFLE 45    DMCT 9    DMCT 21
# DISQ 5    DSE 8    DSE 10
# DSE 10    SRH 55    DSE 86
# DMCT 29    DSE 12    DSE 37
# DSE 23    DISQ 70    DMCT 41
# DISQ 90    DMCT 46    DSE 4
# DMCT 61    DMCT 51    DMCT 46
# DSE 82    SRH 72    DSE 12
# SRH 55    SRH 11    DMCT 47
# DISQ 81    DMCT 57    DSE 23
# DMCT 47    DMCT 39    DMCT 50
# DMCT 39    SRH 26    DISQ 70
# DMCT 57    DMCT 47    DMCT 63
# DMCT 46    DSE 42    SRH 72
# DMCT 63    DMCT 63    DSE 49
# SRH 11    DSE 49    SRH 25
# DSE 49    DMCT 84    DSE 85
# DSE 28    DSE 28    DISQ 75
# DSE 8    SRH 25    DMCT 51
# DMCT 66    DSE 4    DSE 52
# SRH 32    DISQ 90    SRH 83
# DMCT 9    DSE 85    SRH 0
# DMCT 50    DMCT 50    DMCT 84
# DSE 36    DISQ 81    DMCT 57
# DSE 42    SRH 83    DMCT 59
# DMCT 24    DMCT 59    DISQ 81
# DSE 4    SRH 0    DMCT 18
# DMCT 58    DMCT 21    SRH 26
# DSE 37    DSE 56    DSE 73
# DMCT 59    DISQ 75    DISQ 90
# DSE 85    DSE 73    SRH 32
# DSE 53    SRH 32    DSE 28
# SRH 0    DMCT 60    DMCT 24
# DMCT 21    DMCT 24    DMCT 80
# DMCT 80    DSE 53    DSE 56
# DISQ 17    DMCT 80    DMCT 60
# DISQ 75    DMCT 66    DISQ 17
# SFLE 88    DMCT 18    DMCT 1
# DSE 73    DMCT 1    DSE 64
# DMCT 60    DISQ 17    SRH 69
# DMCT 18    SFLE 88    DSE 53
# DSE 64    DSE 64    SFLE 88
# DMCT 1    DSE 36    DSE 36
# DSE 89    SFLE 91    DMCT 66
# DSE 33    DSE 33    SFLE 91
# SRH 69    DSE 89    DISQ 74
# SFLE 91    SRH 69    DISQ 71
# DISQ 74    DISQ 74    DSE 89
# DISQ 71    DSE 3    DSE 3
# DSE 3    DISQ 71    DSE 33
