# %%
import operator
import math

# %%
def bernoulli(p):
    x = randint(0,10^6)
    if x < p*10^6:
        return 1
    else:
        return 0
#change the set V for large graphs
def erdos_renyi_temp(n,tm,p, dire = True):
    g = set()
    V = list( [str(i) for i in range(n)] )
    for t in range(1,tm+1):
        for (a,b) in Combinations(V,2):
            if bernoulli(p):
                if bernoulli(0.5):
                    g.add((a,b,str(t)))
                    if not dire:
                        g.add((b,a,str(t)))
                        
                else:
                    g.add((b,a,str(t)))
                    if not dire:
                        g.add((a,b,str(t)))
                        
                    
    return g    
def to_csv(s,g):
    with open(s,"w") as f:
        for e in g:
            f.write( e[0]+" "+e[1]+" "+e[2]+"\n" )

# %%
import subprocess
path = "../build.build/"
import time
# N = 40
# T = 12
# n = 20
p = 1/(n*T)
def check_time_synth(N,T,n,p,c,typ, which):
    tot = 0
    tot2 = 0
    tot3 = 0
    for _ in range(N):
        g = erdos_renyi_temp(n,T,p)
        print("nb edges", len(g), "nTlog(nT)", n*T*math.log(n*T))
        to_csv('tmp.csv',g)
        if "dij" in which:
            st = time.time()
            subprocess.run([path+"btwBenchmark", "-f", "tmp.csv", "-d","-c",c,"-y",typ]) 
            ed = time.time()
            tot2 += (ed - st)
        if "bell" in which:
            st = time.time()
            subprocess.run([path+"btwBenchmark", "-f", "tmp.csv", "-d","-c",c,"-y",typ,"-z"]) 
            ed = time.time()
            tot += (ed - st)
        if "bfs" in which:
            st = time.time()
            subprocess.run([path+"btwBenchmark", "-f", "tmp.csv", "-d","-c",c,"-y",typ, "-b"]) 
            ed = time.time()
            tot3 += (ed - st)
#     print("average dijkstra ", tot/(N*2*2), "average bellman ", tot2/(N*2*2))
#     print("gain", tot/tot2)
    return tot, tot2, tot3
                
# x = check_time_synth(N,T,n,p)

# %%
#varies nodes small number events
l = []
N = 400
gap = 80
which = ["bell", "dij", "bfs"]
for n in range(4,N+1,gap):
    print(n, " ", end = "")
    T = int(math.sqrt(n))
    p = 2/(T*n)
    repet = 1
    l.append( (n,check_time_synth(repet,T,n,p,"shortest","passive",which)) )
# Out:
# 4  nb edges 2 nTlog(nT) 16.635532333438686
# 0<-
# results saved into files ?0 *0 means no, 1 yes*
# non-strict_shortest_passive
# Dijkstra version!
# pred has no loops speed up ? 0 *0 means no 1 means yes*
# v 0 / 2
# v 1 / 2
# v 2 / 2
# end calcul
# time elapsed : 0.000204677
# non-strict_shortest_passive 0.000204677
# 0<-
# results saved into files ?0 *0 means no, 1 yes*
# non-strict_shortest_passive
# Bellman-Ford version!
# pred has no loops speed up ? 0 *0 means no 1 means yes*
# v 0 / 2
# v 1 / 2
# v 2 / 2
# end calcul
# time elapsed : 0.000183941
# non-strict_shortest_passive 0.000183941
# 0<-
# results saved into files ?0 *0 means no, 1 yes*
# non-strict_shortest_passive
# BFS version!
# looking until inf start time 1 end time 2
# REST = inf 1 2
# end calcul
# 84  time elapsed : 5.535e-05
# non-strict_shortest_passive 5.535e-05
# nb edges 89 nTlog(nT) 5010.799280391727
# 0<-
# results saved into files ?0 *0 means no, 1 yes*
# non-strict_shortest_passive
# Dijkstra version!
# pred has no loops speed up ? 0 *0 means no 1 means yes*
# v 0 / 74
# v 1 / 74
# v 2 / 74
# v 3 / 74
# v 4 / 74
# v 5 / 74
# v 6 / 74
# v 7 / 74
# v 8 / 74
# v 9 / 74
# v 10 / 74
# v 11 / 74
# v 12 / 74
# v 13 / 74
# v 14 / 74
# v 15 / 74
# v 16 / 74
# v 17 / 74
# v 18 / 74
# v 19 / 74
# v 20 / 74
# v 21 / 74
# v 22 / 74
# v 23 / 74
# v 24 / 74
# v 25 / 74
# v 26 / 74
# v 27 / 74
# v 28 / 74
# v 29 / 74
# v 172 / 196
# v 173 / 196
# v 174 / 196
# v 175 / 196
# v 176 / 196
# v 177 / 196
# v 178 / 196
# v 179 / 196
# v 180 / 196
# v 181 / 196
# v 182 / 196
# v 183 / 196
# v 184 / 196
# v 185 / 196
# v 186 / 196
# v 187 / 196
# v 188 / 196
# v 189 / 196
# v 190 / 196
# v 191 / 196
# v 192 / 196
# v 193 / 196
# v 194 / 196
# v 195 / 196
# v 196 / 196
# end calcul
# time elapsed : 52.787
# non-strict_shortest_passive 52.787
# 0<-
# results saved into files ?0 *0 means no, 1 yes*
# non-strict_shortest_passive
# BFS version!
# looking until inf start time 1 end time 15
# REST = inf 1 15
# end calcul
# time elapsed : 0.000753972
# non-strict_shortest_passive 0.000753972
# 324
# Time for algorithms (in seconds):
# Graph read: 197 nodes, 223 (unique) directed edges, 15 (non-empty) timesteps
# Time for algorithms (in seconds):
# nb edges 327 nTlog(nT) 50569.9442761513
# 0<-
# results saved into files ?0 *0 means no, 1 yes*
# non-strict_shortest_passive
# Dijkstra version!
# pred has no loops speed up ? 0 *0 means no 1 means yes*
# v 0 / 282
# v 1 / 282
# v 2 / 282
# v 3 / 282
# v 4 / 282
# v 5 / 282
# v 6 / 282
# v 7 / 282
# v 8 / 282
# v 9 / 282
# v 10 / 282
# v 11 / 282
# v 12 / 282
# v 13 / 282
# v 14 / 282
# v 15 / 282
# v 16 / 282
# v 17 / 282
# v 18 / 282
# v 19 / 282
# v 20 / 282
# v 21 / 282
# v 22 / 282
# v 23 / 282
# v 24 / 282
# v 25 / 282
# v 26 / 282
# v 27 / 282
# v 28 / 282
# v 29 / 282
# v 30 / 282
# v 31 / 282
# v 32 / 282
# v 33 / 282
# v 34 / 282
# v 35 / 282
# v 36 / 282
# v 37 / 282
# v 38 / 282
# v 39 / 282
# v 40 / 282
# v 41 / 282
# v 42 / 282
# v 43 / 282
# v 44 / 282
# v 45 / 282
# v 46 / 282
# v 47 / 282
# v 48 / 282
# v 49 / 282
# v 50 / 282
# v 51 / 282
# v 52 / 282
# v 53 / 282
# v 54 / 282
# v 55 / 282
# v 56 / 282
# v 57 / 282
# v 58 / 282
# v 59 / 282
# v 60 / 282
# v 61 / 282
# v 62 / 282
# v 63 / 282
# v 64 / 282
# v 65 / 282
# v 66 / 282
# v 67 / 282
# v 68 / 282
# v 69 / 282
# v 70 / 282
# v 71 / 282
# v 72 / 282
# v 73 / 282
# v 74 / 282
# v 75 / 282
# v 76 / 282
# v 77 / 282
# v 78 / 282
# v 79 / 282
# v 80 / 282
# v 81 / 282
# v 82 / 282
# v 83 / 282
# v 84 / 282
# v 85 / 282
# v 86 / 282
# v 87 / 282
# v 88 / 282
# v 89 / 282
# v 90 / 282
# v 91 / 282
# v 92 / 282
# v 93 / 282
# v 94 / 282
# v 95 / 282
# v 96 / 282
# v 97 / 282
# v 98 / 282
# v 99 / 282
# v 100 / 282
# v 101 / 282
# v 102 / 282
# v 103 / 282
# v 104 / 282
# v 105 / 282
# v 106 / 282
# v 107 / 282
# v 108 / 282
# v 109 / 282
# v 110 / 282
# v 111 / 282
# v 112 / 282
# v 113 / 282
# v 114 / 282
# v 115 / 282
# v 116 / 282
# v 117 / 282
# v 118 / 282
# v 119 / 282
# v 120 / 282
# v 121 / 282
# v 122 / 282
# v 123 / 282
# v 124 / 282
# v 125 / 282
# v 126 / 282
# v 127 / 282
# v 128 / 282
# v 129 / 282
# v 182 / 282
# v 183 / 282
# v 184 / 282
# v 185 / 282
# v 186 / 282
# v 187 / 282
# v 188 / 282
# v 189 / 282
# v 190 / 282
# v 191 / 282
# v 192 / 282
# v 193 / 282
# v 194 / 282
# v 195 / 282
# v 196 / 282
# v 197 / 282
# v 198 / 282
# v 199 / 282
# v 200 / 282
# v 201 / 282
# v 202 / 282
# v 203 / 282
# v 204 / 282
# v 205 / 282
# v 206 / 282
# v 207 / 282
# v 208 / 282
# v 209 / 282
# v 210 / 282
# v 211 / 282
# v 212 / 282
# v 213 / 282
# v 214 / 282
# v 215 / 282
# v 216 / 282
# v 217 / 282
# v 218 / 282
# v 219 / 282
# v 220 / 282
# v 221 / 282
# v 222 / 282
# v 223 / 282
# v 224 / 282
# v 225 / 282
# v 226 / 282
# v 227 / 282
# v 228 / 282
# v 229 / 282
# v 230 / 282
# v 231 / 282
# v 232 / 282
# v 233 / 282
# v 234 / 282
# v 235 / 282
# v 236 / 282
# v 237 / 282
# v 238 / 282
# v 239 / 282
# v 240 / 282
# v 241 / 282
# v 242 / 282
# v 243 / 282
# v 244 / 282
# v 245 / 282
# v 246 / 282
# v 247 / 282
# v 248 / 282
# v 249 / 282
# v 250 / 282
# v 251 / 282
# v 252 / 282
# v 253 / 282
# v 254 / 282
# v 255 / 282
# v 256 / 282
# v 257 / 282
# v 258 / 282
# v 259 / 282
# v 260 / 282
# v 261 / 282
# v 262 / 282
# v 263 / 282
# v 264 / 282
# v 265 / 282
# v 266 / 282
# v 267 / 282
# v 268 / 282
# v 269 / 282
# v 270 / 282
# v 271 / 282
# v 272 / 282
# v 273 / 282
# v 274 / 282
# v 275 / 282
# v 276 / 282
# v 277 / 282
# v 278 / 282
# v 279 / 282
# v 280 / 282
# v 281 / 282
# v 282 / 282
# end calcul
# time elapsed : 253.089
# non-strict_shortest_passive 253.089
# 0<-
# results saved into files ?0 *0 means no, 1 yes*
# non-strict_shortest_passive
# BFS version!
# looking until inf start time 1 end time 18
# REST = inf 1 18
# end calcul
# time elapsed : 0.00119093
# non-strict_shortest_passive 0.00119093
# Time for algorithms (in seconds):
# Graph read: 283 nodes, 327 (unique) directed edges, 18 (non-empty) timesteps
# Time for algorithms (in seconds):

# %%
#varies nodes small number events
l2 = []
which = ["bell", "dij", "bfs"]
for n in range(4,N+1,gap):
    print(n, " ", end = "")
    T = int(math.sqrt(n))
    p = 2/(T*n)
    repet = 1
    l2.append( (n,check_time_synth(repet,T,n,p,"shortestfastest","passive",which)) )
# Out:
# 4  nb edges 2 nTlog(nT) 16.635532333438686
# 0<-
# results saved into files ?0 *0 means no, 1 yes*
# non-strict_shortestfastest_passive
# Dijkstra version!
# pred has no loops speed up ? 0 *0 means no 1 means yes*
# v 0 / 2
# v 1 / 2
# v 2 / 2
# end calcul
# time elapsed : 0.000177649
# non-strict_shortestfastest_passive 0.000177649
# 0<-
# results saved into files ?0 *0 means no, 1 yes*
# non-strict_shortestfastest_passive
# Bellman-Ford version!
# pred has no loops speed up ? 0 *0 means no 1 means yes*
# v 0 / 2
# v 1 / 2
# v 2 / 2
# end calcul
# time elapsed : 0.000138836
# non-strict_shortestfastest_passive 0.000138836
# 0<-
# results saved into files ?0 *0 means no, 1 yes*
# non-strict_shortestfastest_passive
# BFS version!
# looking until inf start time 2 end time 2
# REST = inf 2 2
# end calcul
# 84  time elapsed : 5.5835e-05
# non-strict_shortestfastest_passive 5.5835e-05
# nb edges 93 nTlog(nT) 5010.799280391727
# 0<-
# results saved into files ?0 *0 means no, 1 yes*
# non-strict_shortestfastest_passive
# Dijkstra version!
# pred has no loops speed up ? 0 *0 means no 1 means yes*
# v 0 /
# v 199 / 214
# v 200 / 214
# v 201 / 214
# v 202 / 214
# v 203 / 214
# v 204 / 214
# v 205 / 214
# v 206 / 214
# v 207 / 214
# v 208 / 214
# v 209 / 214
# v 210 / 214
# v 211 / 214
# v 212 / 214
# v 213 / 214
# v 214 / 214
# end calcul
# time elapsed : 0.0392289
# non-strict_shortestfastest_passive 0.0392289
# Graph read: 215 nodes, 253 (unique) directed edges, 15 (non-empty) timesteps
# Time for algorithms (in seconds):
# Graph read: 215 nodes, 253 (unique) directed edges, 15 (non-empty) timesteps
# 0<-
# results saved into files ?0 *0 means no, 1 yes*
# non-strict_shortestfastest_passive
# Bellman-Ford version!
# pred has no loops speed up ? 0 *0 means no 1 means yes*
# v 0 / 214
# v 1 / 214
# v 2 / 214
# v 3 / 214
# v 4 / 214
# v 5 / 214
# v 6 / 214
# v 7 / 214
# v 8 / 214
# v 9 / 214
# v 10 / 214
# v 11 / 214
# v 12 / 214
# v 13 / 214
# v 14 / 214
# v 15 / 214
# v 16 / 214
# v 17 / 214
# v 18 / 214
# v 19 / 214
# v 20 / 214
# v 21 / 214
# v 22 / 214
# v 23 / 214
# v 24 / 214
# v 25 / 214
# v 26 / 214
# v 27 / 214
# v 28 / 214
# v 29 / 214
# v 30 / 214
# v 31 / 214
# v 32 / 214
# v 33 / 214
# v 34 / 214
# v 35 / 214
# v 36 / 214
# v 37 / 214
# v 38 / 214
# v 39 / 214
# v 40 / 214
# v 41 / 214
# v 42 / 214
# v 43 / 214
# v 44 / 214
# v 45 / 214
# v 46 / 214
# v 47 / 214
# v 48 / 214
# v 49 / 214
# v 50 / 214
# v 51 / 214
# v 52 / 214
# v 53 / 214
# v 54 / 214
# v 55 / 214
# v 56 / 214
# v 57 / 214
# v 58 / 214
# v 59 / 214
# v 60 / 214
# v 61 / 214
# v 62 / 214
# v 63 / 214
# v 64 / 214
# v 65 / 214
# v 66 / 214
# v 67 / 214
# v 68 / 214
# v 69 / 214
# v 70 / 214
# v 71 / 214
# v 72 / 214
# v 73 / 214
# v 74 / 214
# v 75 / 214
# v 76 / 214
# v 77 / 214
# v 78 / 214
# v 79 / 214
# v 80 / 214
# v 81 / 214
# v 82 / 214
# v 83 / 214
# v 84 / 214
# v 85 / 214
# v 86 / 214
# v 87 / 214
# v 88 / 214
# v 89 / 214
# v 90 / 214
# v 91 / 214
# v 92 / 214
# v 93 / 214
# v 94 / 214
# v 95 / 214
# v 96 / 214
# v 97 / 214
# v 98 / 214
# v 99 / 214
# v 100 / 214
# v 101 / 214
# v 102 / 214
# v 103 / 214
# v 104 / 214
# v 105 / 214
# v 106 / 214
# v 107 / 214
# v 108 / 214
# v 109 / 214
# v 110 / 214
# v 111 / 214
# v 112 / 214
# v 113 / 214
# v 114 / 214
# v 115 / 214
# v 116 / 214
# v 117 / 214
# v 118 / 214
# v 119 / 214
# v 120 / 214
# v 121 / 214
# v 122 / 214
# v 123 / 214
# v 124 / 214
# v 125 / 214
# v 126 / 214
# v 127 / 214
# v 128 / 214
# v 129 / 214
# v 130 / 214
# v 131 / 214
# v 132 / 214
# v 133 / 214
# v 134 / 214
# v 135 / 214
# v 136 / 214
# v 137 / 214
# v 138 / 214
# v 139 / 214
# v 140 / 214
# v 141 / 214
# v 142 / 214
# v 143 / 214
# v 144 / 214
# v 145 / 214
# v 146 / 214
# v 147 / 214
# v 148 / 214
# v 149 / 214
# v 150 / 214
# v 151 / 214
# v 152 / 214
# v 153 / 214
# v 154 / 214
# v 155 / 214
# v 156 / 214
# v 157 / 214
# v 158 / 214
# v 159 / 214
# v 160 / 214
# v 161 / 214
# v 162 / 214
# v 163 / 214
# v 164 / 214
# v 165 / 214
# v 166 / 214
# v 167 / 214
# v 168 / 214
# v 169 / 214
# v 170 / 214
# v 171 / 214
# v 172 / 214
# v 173 / 214
# v 174 / 214
# v 175 / 214
# v 176 / 214
# v 177 / 214
# v 178 / 214
# v 179 / 214
# v 180 / 214
# v 181 / 214
# v 182 / 214
# v 183 / 214
# v 184 / 214
# v 185 / 214
# v 186 / 214
# v 187 / 214
# v 188 / 214
# v 189 / 214
# v 190 / 214
# v 191 / 214
# v 192 / 214
# v 193 / 214
# v 194 / 214
# v 195 / 214
# v 196 / 214
# v 197 / 214
# v 198 / 214
# v 199 / 214
# v 200 / 214
# v 201 / 214
# v 202 / 214
# v 203 / 214
# v 204 / 214
# v 205 / 214
# v 206 / 214
# v 207 / 214
# v 208 / 214
# v 209 / 214
# v 210 / 214
# v 211 / 214
# v 212 / 214
# v 213 / 214
# v 214 / 214
# end calcul
# time elapsed : 77.903
# non-strict_shortestfastest_passive 77.903
# 0<-
# results saved into files ?0 *0 means no, 1 yes*
# non-strict_shortestfastest_passive
# BFS version!
# looking until inf start time 1 end time 15
# REST = inf 1 15
# end calcul
# time elapsed : 0.000814665
# non-strict_shortestfastest_passive 0.000814665
# 324
# Time for algorithms (in seconds):
# Graph read: 215 nodes, 253 (unique) directed edges, 15 (non-empty) timesteps
# Time for algorithms (in seconds):
# nb edges 306 nTlog(nT) 50569.9442761513
# 0<-
# results saved into files ?0 *0 means no, 1 yes*
# non-strict_shortestfastest_passive
# Dijkstra version!
# pred has no loops speed up ? 0 *0 means no 1 means yes*
# v 0 / 275
# v 1 / 275
# v 2 / 275
# v 3 / 275
# v 4 / 275
# v 5 / 275
# v 6 / 275
# v 7 / 275
# v 8 / 275
# v 9 / 275
# v 10 / 275
# v 11 / 275
# v 12 / 275
# v 13 / 275
# v 14 / 275
# v 15 / 275
# v 16 / 275
# v 17 / 275
# v 18 / 275
# v 19 / 275
# v 20 / 275
# v 21 / 275
# v 22 / 275
# v 23 / 275
# v 24 / 275
# v 25 / 275
# v 26 / 275
# v 27 / 275
# v 28 / 275
# v 29 / 275
# v 30 / 275
# v 31 / 275
# v 32 / 275
# v 33 / 275
# v 34 / 275
# v 35 / 275
# v 36 / 275
# v 37 / 275
# v 38 / 275
# v 39 / 275
# v 40 / 275
# v 41 / 275
# v 42 / 275
# v 43 / 275
# v 44 / 275
# v 45 / 275
# v 46 / 275
# v 47 / 275
# v 48 / 275
# v 49 / 275
# v 50 / 275
# v 51 / 275
# v 52 / 275
# v 53 / 275
# v 54 / 275
# v 55 / 275
# v 56 / 275
# v 57 / 275
# v 58 / 275
# v 59 / 275
# v 60 / 275
# v 61 / 275
# v 62 / 275
# v 63 / 275
# v 64 / 275
# v 65 / 275
# v 66 / 275
# v 67 / 275
# v 68 / 275
# v 69 / 275
# v 70 / 275
# v 71 / 275
# v 72 / 275
# v 73 / 275
# v 74 / 275
# v 75 / 275
# v 76 / 275
# v 77 / 275
# v 78 / 275
# v 79 / 275
# v 80 / 275
# v 81 / 275
# v 82 / 275
# v 83 / 275
# v 84 / 275
# v 85 / 275
# v 86 / 275
# v 87 / 275
# v 88 / 275
# v 89 / 275
# v 90 / 275
# v 91 / 275
# v 92 / 275
# v 93 / 275
# v 94 / 275
# v 95 / 275
# v 96 / 275
# v 97 / 275
# v 98 / 275
# v 99 / 275
# v 100 / 275
# v 101 / 275
# v 102 / 275
# v 103 / 275
# v 104 / 275
# v 105 / 275
# v 106 / 275
# v 107 / 275
# v 108 / 275
# v 109 / 275
# v 110 / 275
# v 111 / 275
# v 112 / 275
# v 113 / 275
# v 114 / 275
# v 115 / 275
# v 116 / 275
# v 117 / 275
# v 118 / 275
# v 119 / 275
# v 120 / 275
# v 121 / 275
# v 122 / 275
# v 123 / 275
# v 124 / 275
# v 125 / 275
# v 126 / 275
# v 127 / 275
# v 128 / 275
# v 129 / 275
# v 130 / 275
# v 131 / 275
# v 132 / 275
# v 133 / 275
# v 134 / 275
# v 135 / 275
# v 136 / 275
# v 137 / 275
# v 138 / 275
# v 139 / 275
# v 140 / 275
# v 141 / 275
# v 142 / 275
# v 143 / 275
# v 144 / 275
# v 145 / 275
# v 146 / 275
# v 147 / 275
# v 148 / 275
# v 149 / 275
# v 150 / 275
# v 151 / 275
# v 152 / 275
# v 153 / 275
# v 154 / 275
# v 155 / 275
# v 156 / 275
# v 157 / 275
# v 158 / 275
# v 159 / 275
# v 160 / 275
# v 161 / 275
# v 162 / 275
# v 163 / 275
# v 164 / 275
# v 165 / 275
# v 166 / 275
# v 167 / 275
# v 168 / 275
# v 169 / 275
# v 170 / 275
# v 171 / 275
# v 172 / 275
# v 173 / 275
# v 174 / 275
# v 175 / 275
# v 176 / 275
# v 177 / 275
# v 178 / 275
# v 179 / 275
# v 180 / 275
# v 181 / 275
# v 182 / 275
# v 183 / 275
# v 184 / 275
# v 185 / 275
# v 186 / 275
# v 187 / 275
# v 188 / 275
# v 189 / 275
# v 190 / 275
# v 191 / 275
# v 192 / 275
# v 193 / 275
# v 194 / 275
# v 195 / 275
# v 196 / 275
# v 197 / 275
# v 198 / 275
# v 199 / 275
# v 200 / 275
# v 201 / 275
# v 202 / 275
# v 203 / 275
# v 204 / 275
# v 205 / 275
# v 206 / 275
# v 207 / 275
# v 208 / 275
# v 209 / 275
# v 210 / 275
# v 211 / 275
# v 212 / 275
# v 213 / 275
# v 214 / 275
# v 215 / 275
# v 216 / 275
# v 217 / 275
# v 218 / 275
# v 219 / 275
# v 220 / 275
# v 221 / 275
# v 222 / 275
# v 223 / 275
# v 224 / 275
# v 225 / 275
# v 226 / 275
# v 227 / 275
# v 228 / 275
# v 229 / 275
# v 230 / 275
# v 231 / 275
# v 232 / 275
# v 233 / 275
# v 234 / 275
# v 235 / 275
# v 236 / 275
# v 237 / 275
# v 238 / 275
# v 239 / 275
# v 240 / 275
# v 241 / 275
# v 242 / 275
# v 243 / 275
# v 244 / 275
# v 245 / 275
# v 246 / 275
# v 247 / 275
# v 248 / 275
# v 249 / 275
# v 250 / 275
# v 251 / 275
# v 252 / 275
# v 253 / 275
# v 254 / 275
# v 255 / 275
# v 256 / 275
# v 257 / 275
# v 258 / 275
# v 259 / 275
# v 260 / 275
# v 261 / 275
# v 262 / 275
# v 263 / 275
# v 264 / 275
# v 265 / 275
# v 266 / 275
# v 267 / 275
# v 268 / 275
# v 269 / 275
# v 270 / 275
# v 271 / 275
# v 272 / 275
# v 273 / 275
# v 274 / 275
# v 275 / 275
# end calcul
# time elapsed : 0.0428409
# non-strict_shortestfastest_passive 0.0428409
# Graph read: 276 nodes, 306 (unique) directed edges, 18 (non-empty) timesteps
# Time for algorithms (in seconds):
# Graph read: 276 nodes, 306 (unique) directed edges, 18 (non-empty) timesteps
# 0<-
# results saved into files ?0 *0 means no, 1 yes*
# non-strict_shortestfastest_passive
# Bellman-Ford version!
# pred has no loops speed up ? 0 *0 means no 1 means yes*
# v 0 / 275
# v 1 / 275
# v 2 / 275
# v 3 / 275
# v 4 / 275
# v 5 / 275
# v 6 / 275
# v 7 / 275
# v 8 / 275
# v 9 / 275
# v 10 / 275
# v 11 / 275
# v 12 / 275
# v 13 / 275
# v 14 / 275
# v 15 / 275
# v 16 / 275
# v 17 / 275
# v 18 / 275
# v 19 / 275
# v 20 / 275
# v 21 / 275
# v 22 / 275
# v 23 / 275
# v 24 / 275
# v 25 / 275
# v 26 / 275
# v 27 / 275
# v 28 / 275
# v 29 / 275
# v 30 / 275
# v 31 / 275
# v 32 / 275
# v 33 / 275
# v 34 / 275
# v 35 / 275
# v 36 / 275
# v 37 / 275
# v 38 / 275
# v 39 / 275
# v 40 / 275
# v 41 / 275
# v 42 / 275
# v 43 / 275
# v 44 / 275
# v 45 / 275
# v 46 / 275
# v 47 / 275
# v 48 / 275
# v 49 / 275
# v 50 / 275
# v 51 / 275
# v 52 / 275
# v 53 / 275
# v 54 / 275
# v 55 / 275
# v 56 / 275
# v 57 / 275
# v 58 / 275
# v 59 / 275
# v 60 / 275
# v 61 / 275
# v 62 / 275
# v 63 / 275
# v 64 / 275
# v 65 / 275
# v 66 / 275
# v 67 / 275
# v 68 / 275
# v 69 / 275
# v 70 / 275
# v 71 / 275
# v 72 / 275
# v 73 / 275
# v 74 / 275
# v 75 / 275
# v 76 / 275
# v 77 / 275
# v 78 / 275
# v 79 / 275
# v 80 / 275
# v 81 / 275
# v 82 / 275
# v 83 / 275
# v 84 / 275
# v 85 / 275
# v 86 / 275
# v 87 / 275
# v 88 / 275
# v 89 / 275
# v 90 / 275
# v 91 / 275
# v 92 / 275
# v 93 / 275
# v 94 / 275
# v 95 / 275
# v 96 / 275
# v 97 / 275
# v 98 / 275
# v 99 / 275
# v 100 / 275
# v 101 / 275
# v 102 / 275
# v 103 / 275
# v 104 / 275
# v 105 / 275
# v 106 / 275
# v 107 / 275
# v 108 / 275
# v 109 / 275
# v 110 / 275
# v 111 / 275
# v 112 / 275
# v 113 / 275
# v 114 / 275
# v 115 / 275
# v 116 / 275
# v 117 / 275
# v 118 / 275
# v 119 / 275
# v 120 / 275
# v 121 / 275
# v 122 / 275
# v 123 / 275
# v 124 / 275
# v 125 / 275
# v 126 / 275
# v 127 / 275
# v 128 / 275
# v 129 / 275
# v 130 / 275
# v 131 / 275
# v 132 / 275
# v 133 / 275
# v 134 / 275
# v 135 / 275
# v 136 / 275
# v 137 / 275
# v 138 / 275
# v 139 / 275
# v 140 / 275
# v 141 / 275
# v 142 / 275
# v 143 / 275
# v 144 / 275
# v 145 / 275
# v 146 / 275
# v 147 / 275
# v 148 / 275
# v 149 / 275
# v 150 / 275
# v 151 / 275
# v 152 / 275
# v 153 / 275
# v 154 / 275
# v 155 / 275
# v 156 / 275
# v 157 / 275
# v 158 / 275
# v 159 / 275
# v 160 / 275
# v 161 / 275
# v 162 / 275
# v 163 / 275
# v 164 / 275
# v 165 / 275
# v 166 / 275
# v 167 / 275
# v 168 / 275
# v 169 / 275
# v 170 / 275
# v 171 / 275
# v 172 / 275
# v 173 / 275
# v 174 / 275
# v 175 / 275
# v 176 / 275
# v 177 / 275
# v 178 / 275
# v 179 / 275
# v 180 / 275
# v 181 / 275
# v 182 / 275
# v 183 / 275
# v 184 / 275
# v 185 / 275
# v 186 / 275
# v 187 / 275
# v 188 / 275
# v 189 / 275
# v 190 / 275
# v 191 / 275
# v 192 / 275
# v 193 / 275
# v 194 / 275
# v 195 / 275
# v 196 / 275
# v 197 / 275
# v 198 / 275
# v 199 / 275
# v 200 / 275
# v 201 / 275
# v 202 / 275
# v 203 / 275
# v 204 / 275
# v 205 / 275
# v 206 / 275
# v 207 / 275
# v 208 / 275
# v 209 / 275
# v 210 / 275
# v 211 / 275
# v 212 / 275
# v 213 / 275
# v 214 / 275
# v 215 / 275
# v 216 / 275
# v 217 / 275
# v 218 / 275
# v 219 / 275
# v 220 / 275
# v 221 / 275
# v 222 / 275
# v 223 / 275
# v 224 / 275
# v 225 / 275
# v 226 / 275
# v 227 / 275
# v 228 / 275
# v 229 / 275
# v 230 / 275
# v 231 / 275
# v 232 / 275
# v 233 / 275
# v 234 / 275
# v 235 / 275
# v 236 / 275
# v 237 / 275
# v 238 / 275
# v 239 / 275
# v 240 / 275
# v 241 / 275
# v 242 / 275
# v 243 / 275
# v 244 / 275
# v 245 / 275
# v 246 / 275
# v 247 / 275
# v 248 / 275
# v 249 / 275
# v 250 / 275
# v 251 / 275
# v 252 / 275
# v 253 / 275
# v 254 / 275
# v 255 / 275
# v 256 / 275
# v 257 / 275
# v 258 / 275
# v 259 / 275
# v 260 / 275
# v 261 / 275
# v 262 / 275
# v 263 / 275
# v 264 / 275
# v 265 / 275
# v 266 / 275
# v 267 / 275
# v 268 / 275
# v 269 / 275
# v 270 / 275
# v 271 / 275
# v 272 / 275
# v 273 / 275
# v 274 / 275
# v 275 / 275
# end calcul
# time elapsed : 236.71
# non-strict_shortestfastest_passive 236.71
# 0<-
# results saved into files ?0 *0 means no, 1 yes*
# non-strict_shortestfastest_passive
# BFS version!
# looking until inf start time 1 end time 18
# REST = inf 1 18
# end calcul
# time elapsed : 0.00104654
# non-strict_shortestfastest_passive 0.00104654
# Time for algorithms (in seconds):
# Graph read: 276 nodes, 306 (unique) directed edges, 18 (non-empty) timesteps
# Time for algorithms (in seconds):

# %%
import matplotlib.pyplot as plt 
labels = which
fig, ax = plt.subplots(layout='constrained')

for i in range(0,len(which),1):
    plt.plot(list(map(lambda x : x[0], l)), list(map(lambda x : x[1][i], l)), label = labels[i]+"_sh" )
for i in range(0,len(which)-1,1):
    plt.plot(list(map(lambda x : x[0], l2)), list(map(lambda x : x[1][i], l2)), label = labels[i]+"_shf" )

plt.legend()
ax.set_yscale('log')
ax.set_ylabel('Time in sec')
ax.set_xlabel('# nodes')
plt.savefig('sh_n.png', dpi=300)

plt.show()

# %%
#varies times
l = []
N = 600
for T in range(4,N+1,gap):
    print("T",T)
    n = int(math.sqrt(T))
    print("n,T",n,T, " ", end = "")
    p = 10/(T*n)
    repet = 1
    l.append( (T,check_time_synth(repet,T,n,p,"shortest","passive",which)) )
# Out:
# T 4
# n,T 2 4  nb edges 4 nTlog(nT) 16.635532333438686
# 0<-
# results saved into files ?0 *0 means no, 1 yes*
# non-strict_shortest_passive
# Dijkstra version!
# pred has no loops speed up ? 0 *0 means no 1 means yes*
# v 0 / 1
# v 1 / 1
# end calcul
# time elapsed : 0.000224012
# non-strict_shortest_passive 0.000224012
# 0<-
# results saved into files ?0 *0 means no, 1 yes*
# non-strict_shortest_passive
# Bellman-Ford version!
# pred has no loops speed up ? 0 *0 means no 1 means yes*
# v 0 / 1
# v 1 / 1
# end calcul
# time elapsed : 0.000189941
# non-strict_shortest_passive 0.000189941
# 0<-
# results saved into files ?0 *0 means no, 1 yes*
# non-strict_shortest_passive
# BFS version!
# looking until inf start time 1 end time 4
# REST = inf 1 4
# end calcul
# time elapsed : 3.4068e-05
# non-strict_shortest_passive 3.4068e-05
# T 84
# n,T 9 84  nb edges 39 nTlog(nT) 5010.799280391727
# 0<-
# results saved into files ?0 *0 means no, 1 yes*
# non-strict_shortest_passive
# Dijkstra version!
# pred has no loops speed up ? 0 *0 means no 1 means yes*
# v 0 / 8
# v 1 / 8
# v 2 / 8
# v 3 / 8
# v 4 / 8
# v 5 / 8
# v 6 / 8
# v 7 / 8
# v 8 / 8
# end calcul
# time elapsed : 0.00245044
# non-strict_shortest_passive 0.00245044
# 0<-
# results saved into files ?0 *0 means no, 1 yes*
# non-strict_shortest_passive
# Bellman-Ford version!
# pred has no loops speed up ? 0 *0 means no 1 means yes*
# v 0 / 8
# v 1 / 8
# v 2 / 8
# v 3 / 8
# v 4 / 8
# v 5 / 8
# v 6 / 8
# v 7 / 8
# v 8 / 8
# end calcul
# time elapsed : 0.0346982
# non-strict_shortest_passive 0.0346982
# 0<-
# results saved into files ?0 *0 means no, 1 yes*
# non-strict_shortest_passive
# BFS version!
# looking until inf start time 3 end time 84
# REST = inf 3 84
# end calcul
# time elapsed : 0.000217065
# non-strict_shortest_passive 0.000217065
# T 164
# n,T 12 164  nb edges 57 nTlog(nT) 14926.833416740807
# 0<-
# results saved into files ?0 *0 means no, 1 yes*
# non-strict_shortest_passive
# Dijkstra version!
# pred has no loops speed up ? 0 *0 means no 1 means yes*
# v 0 / 11
# v 1 / 11
# v 2 / 11
# v 3 / 11
# v 4 / 11
# v 5 / 11
# v 6 / 11
# v 7 / 11
# v 8 / 11
# v 9 / 11
# v 10 / 11
# v 11 / 11
# end calcul
# time elapsed : 0.00312747
# non-strict_shortest_passive 0.00312747
# Graph read: 2 nodes, 4 (unique) directed edges, 4 (non-empty) timesteps
# Time for algorithms (in seconds):
# Graph read: 2 nodes, 4 (unique) directed edges, 4 (non-empty) timesteps
# Time for algorithms (in seconds):
# Graph read: 2 nodes, 4 (unique) directed edges, 4 (non-empty) timesteps
# Time for algorithms (in seconds):
# Graph read: 9 nodes, 39 (unique) directed edges, 30 (non-empty) timesteps
# Time for algorithms (in seconds):
# Graph read: 9 nodes, 39 (unique) directed edges, 30 (non-empty) timesteps
# Time for algorithms (in seconds):
# Graph read: 9 nodes, 39 (unique) directed edges, 30 (non-empty) timesteps
# Time for algorithms (in seconds):
# Graph read: 12 nodes, 57 (unique) directed edges, 45 (non-empty) timesteps
# Time for algorithms (in seconds):
# Graph read: 12 nodes, 57 (unique) directed edges, 45 (non-empty) timesteps
# Time for algorithms (in seconds):
# Graph read: 12 nodes, 57 (unique) directed edges, 45 (non-empty) timesteps
# Time for algorithms (in seconds):
# Graph read: 15 nodes, 72 (unique) directed edges, 64 (non-empty) timesteps
# Time for algorithms (in seconds):
# Graph read: 15 nodes, 72 (unique) directed edges, 64 (non-empty) timesteps
# 0<-
# results saved into files ?0 *0 means no, 1 yes*
# non-strict_shortest_passive
# Bellman-Ford version!
# pred has no loops speed up ? 0 *0 means no 1 means yes*
# v 0 / 11
# v 1 / 11
# v 2 / 11
# v 3 / 11
# v 4 / 11
# v 5 / 11
# v 6 / 11
# v 7 / 11
# v 8 / 11
# v 9 / 11
# v 10 / 11
# v 11 / 11
# end calcul
# time elapsed : 0.301248
# non-strict_shortest_passive 0.301248
# 0<-
# results saved into files ?0 *0 means no, 1 yes*
# non-strict_shortest_passive
# BFS version!
# looking until inf start time 2 end time 162
# REST = inf 2 162
# end calcul
# time elapsed : 0.000316735
# non-strict_shortest_passive 0.000316735
# T 244
# n,T 15 244  nb edges 72 nTlog(nT) 30031.099440607206
# 0<-
# results saved into files ?0 *0 means no, 1 yes*
# non-strict_shortest_passive
# Dijkstra version!
# pred has no loops speed up ? 0 *0 means no 1 means yes*
# v 0 / 14
# v 1 / 14
# v 2 / 14
# v 3 / 14
# v 4 / 14
# v 5 / 14
# v 6 / 14
# v 7 / 14
# v 8 / 14
# v 9 / 14
# v 10 / 14
# v 11 / 14
# v 12 / 14
# v 13 / 14
# v 14 / 14
# end calcul
# time elapsed : 0.0046846
# non-strict_shortest_passive 0.0046846
# 0<-
# results saved into files ?0 *0 means no, 1 yes*
# non-strict_shortest_passive
# Bellman-Ford version!
# pred has no loops speed up ? 0 *0 means no 1 means yes*
# v 0 / 14
# v 1 / 14
# v 2 / 14
# v 3 / 14
# v 4 / 14
# v 5 / 14
# v 6 / 14
# v 7 / 14
# v 8 / 14
# v 9 / 14
# v 10 / 14
# v 11 / 14
# v 12 / 14
# v 13 / 14
# v 14 / 14
# end calcul
# time elapsed : 1.41178
# non-strict_shortest_passive 1.41178
# 0<-
# results saved into files ?0 *0 means no, 1 yes*
# non-strict_shortest_passive
# BFS version!
# looking until inf start time 1 end time 244
# REST = inf 1 244
# end calcul
# time elapsed : 0.000411267
# non-strict_shortest_passive 0.000411267
# T 324
# n,T 18 324
# Time for algorithms (in seconds):
# Graph read: 15 nodes, 72 (unique) directed edges, 64 (non-empty) timesteps
# Time for algorithms (in seconds):
# nb edges 82 nTlog(nT) 50569.9442761513
# 0<-
# results saved into files ?0 *0 means no, 1 yes*
# non-strict_shortest_passive
# Dijkstra version!
# pred has no loops speed up ? 0 *0 means no 1 means yes*
# v 0 / 17
# v 1 / 17
# v 2 / 17
# v 3 / 17
# v 4 / 17
# v 5 / 17
# v 6 / 17
# v 7 / 17
# v 8 / 17
# v 9 / 17
# v 10 / 17
# v 11 / 17
# v 12 / 17
# v 13 / 17
# v 14 / 17
# v 15 / 17
# v 16 / 17
# v 17 / 17
# end calcul
# time elapsed : 0.00869193
# non-strict_shortest_passive 0.00869193
# Graph read: 18 nodes, 82 (unique) directed edges, 75 (non-empty) timesteps
# Time for algorithms (in seconds):
# Graph read: 18 nodes, 82 (unique) directed edges, 75 (non-empty) timesteps
# 0<-
# results saved into files ?0 *0 means no, 1 yes*
# non-strict_shortest_passive
# Bellman-Ford version!
# pred has no loops speed up ? 0 *0 means no 1 means yes*
# v 0 / 17
# v 1 / 17
# v 2 / 17
# v 3 / 17
# v 4 / 17
# v 5 / 17
# v 6 / 17
# v 7 / 17
# v 8 / 17
# v 9 / 17
# v 10 / 17
# v 11 / 17
# v 12 / 17
# v 13 / 17
# v 14 / 17
# v 15 / 17
# v 16 / 17
# v 17 / 17
# end calcul
# time elapsed : 3.68203
# non-strict_shortest_passive 3.68203
# 0<-
# results saved into files ?0 *0 means no, 1 yes*
# non-strict_shortest_passive
# BFS version!
# looking until inf start time 6 end time 324
# REST = inf 6 324
# end calcul
# time elapsed : 0.000395823
# non-strict_shortest_passive 0.000395823
# T 404
# n,T 20 404
# Time for algorithms (in seconds):
# Graph read: 18 nodes, 82 (unique) directed edges, 75 (non-empty) timesteps
# Time for algorithms (in seconds):
# nb edges 87 nTlog(nT) 72696.94898424235
# 0<-
# results saved into files ?0 *0 means no, 1 yes*
# non-strict_shortest_passive
# Dijkstra version!
# pred has no loops speed up ? 0 *0 means no 1 means yes*
# v 0 / 19
# v 1 / 19
# v 2 / 19
# v 3 / 19
# v 4 / 19
# v 5 / 19
# v 6 / 19
# v 7 / 19
# v 8 / 19
# v 9 / 19
# v 10 / 19
# v 11 / 19
# v 12 / 19
# v 13 / 19
# v 14 / 19
# v 15 / 19
# v 16 / 19
# v 17 / 19
# v 18 / 19
# v 19 / 19
# end calcul
# time elapsed : 0.00692652
# non-strict_shortest_passive 0.00692652
# Graph read: 20 nodes, 87 (unique) directed edges, 75 (non-empty) timesteps
# Time for algorithms (in seconds):
# Graph read: 20 nodes, 87 (unique) directed edges, 75 (non-empty) timesteps
# 0<-
# results saved into files ?0 *0 means no, 1 yes*
# non-strict_shortest_passive
# Bellman-Ford version!
# pred has no loops speed up ? 0 *0 means no 1 means yes*
# v 0 / 19
# v 1 / 19
# v 2 / 19
# v 3 / 19
# v 4 / 19
# v 5 / 19
# v 6 / 19
# v 7 / 19
# v 8 / 19
# v 9 / 19
# v 10 / 19
# v 11 / 19
# v 12 / 19
# v 13 / 19
# v 14 / 19
# v 15 / 19
# v 16 / 19
# v 17 / 19
# v 18 / 19
# v 19 / 19
# end calcul
# time elapsed : 4.85974
# non-strict_shortest_passive 4.85974
# 0<-
# results saved into files ?0 *0 means no, 1 yes*
# non-strict_shortest_passive
# BFS version!
# looking until inf start time 23 end time 404
# REST = inf 23 404
# end calcul
# time elapsed : 0.000614792
# non-strict_shortest_passive 0.000614792
# T 484
# n,T 22 484
# Time for algorithms (in seconds):
# Graph read: 20 nodes, 87 (unique) directed edges, 75 (non-empty) timesteps
# Time for algorithms (in seconds):
# nb edges 99 nTlog(nT) 98740.26013007805
# 0<-
# results saved into files ?0 *0 means no, 1 yes*
# non-strict_shortest_passive
# Dijkstra version!
# pred has no loops speed up ? 0 *0 means no 1 means yes*
# v 0 / 21
# v 1 / 21
# v 2 / 21
# v 3 / 21
# v 4 / 21
# v 5 / 21
# v 6 / 21
# v 7 / 21
# v 8 / 21
# v 9 / 21
# v 10 / 21
# v 11 / 21
# v 12 / 21
# v 13 / 21
# v 14 / 21
# v 15 / 21
# v 16 / 21
# v 17 / 21
# v 18 / 21
# v 19 / 21
# v 20 / 21
# v 21 / 21
# end calcul
# time elapsed : 0.00889691
# non-strict_shortest_passive 0.00889691
# Graph read: 22 nodes, 99 (unique) directed edges, 91 (non-empty) timesteps
# Time for algorithms (in seconds):
# Graph read: 22 nodes, 99 (unique) directed edges, 91 (non-empty) timesteps
# 0<-
# results saved into files ?0 *0 means no, 1 yes*
# non-strict_shortest_passive
# Bellman-Ford version!
# pred has no loops speed up ? 0 *0 means no 1 means yes*
# v 0 / 21
# v 1 / 21
# v 2 / 21
# v 3 / 21
# v 4 / 21
# v 5 / 21
# v 6 / 21
# v 7 / 21
# v 8 / 21
# v 9 / 21
# v 10 / 21
# v 11 / 21
# v 12 / 21
# v 13 / 21
# v 14 / 21
# v 15 / 21
# v 16 / 21
# v 17 / 21
# v 18 / 21
# v 19 / 21
# v 20 / 21
# v 21 / 21
# end calcul
# time elapsed : 9.667
# non-strict_shortest_passive 9.667
# 0<-
# results saved into files ?0 *0 means no, 1 yes*
# non-strict_shortest_passive
# BFS version!
# looking until inf start time 6 end time 473
# REST = inf 6 473
# end calcul
# time elapsed : 0.000601798
# non-strict_shortest_passive 0.000601798
# T 564
# n,T 23 564
# Time for algorithms (in seconds):
# Graph read: 22 nodes, 99 (unique) directed edges, 91 (non-empty) timesteps
# Time for algorithms (in seconds):
# nb edges 118 nTlog(nT) 122851.95471946575
# 0<-
# results saved into files ?0 *0 means no, 1 yes*
# non-strict_shortest_passive
# Dijkstra version!
# pred has no loops speed up ? 0 *0 means no 1 means yes*
# v 0 / 22
# v 1 / 22
# v 2 / 22
# v 3 / 22
# v 4 / 22
# v 5 / 22
# v 6 / 22
# v 7 / 22
# v 8 / 22
# v 9 / 22
# v 10 / 22
# v 11 / 22
# v 12 / 22
# v 13 / 22
# v 14 / 22
# v 15 / 22
# v 16 / 22
# v 17 / 22
# v 18 / 22
# v 19 / 22
# v 20 / 22
# v 21 / 22
# v 22 / 22
# end calcul
# time elapsed : 0.0105857
# non-strict_shortest_passive 0.0105857
# Graph read: 23 nodes, 118 (unique) directed edges, 108 (non-empty) timesteps
# Time for algorithms (in seconds):
# Graph read: 23 nodes, 118 (unique) directed edges, 108 (non-empty) timesteps
# 0<-
# results saved into files ?0 *0 means no, 1 yes*
# non-strict_shortest_passive
# Bellman-Ford version!
# pred has no loops speed up ? 0 *0 means no 1 means yes*
# v 0 / 22
# v 1 / 22
# v 2 / 22
# v 3 / 22
# v 4 / 22
# v 5 / 22
# v 6 / 22
# v 7 / 22
# v 8 / 22
# v 9 / 22
# v 10 / 22
# v 11 / 22
# v 12 / 22
# v 13 / 22
# v 14 / 22
# v 15 / 22
# v 16 / 22
# v 17 / 22
# v 18 / 22
# v 19 / 22
# v 20 / 22
# v 21 / 22
# v 22 / 22
# end calcul
# time elapsed : 19.2097
# non-strict_shortest_passive 19.2097
# 0<-
# results saved into files ?0 *0 means no, 1 yes*
# non-strict_shortest_passive
# BFS version!
# looking until inf start time 15 end time 564
# REST = inf 15 564
# end calcul
# time elapsed : 0.000866274
# non-strict_shortest_passive 0.000866274
# Time for algorithms (in seconds):
# Graph read: 23 nodes, 118 (unique) directed edges, 108 (non-empty) timesteps
# Time for algorithms (in seconds):

# %%
#varies times
l2 = []
for T in range(4,N+1,gap):
    print("T",T)
    n = int(math.sqrt(T))
    print("n,T",n,T, " ", end = "")
    p = 10/(T*n)
    repet = 1
    l2.append( (T,check_time_synth(repet,T,n,p,"shortestfastest","passive",which)) )
# Out:
# T 4
# n,T 2 4  nb edges 4 nTlog(nT) 16.635532333438686
# 0<-
# results saved into files ?0 *0 means no, 1 yes*
# non-strict_shortestfastest_passive
# Dijkstra version!
# pred has no loops speed up ? 0 *0 means no 1 means yes*
# v 0 / 1
# v 1 / 1
# end calcul
# time elapsed : 0.000674096
# non-strict_shortestfastest_passive 0.000674096
# 0<-
# results saved into files ?0 *0 means no, 1 yes*
# non-strict_shortestfastest_passive
# Bellman-Ford version!
# pred has no loops speed up ? 0 *0 means no 1 means yes*
# v 0 / 1
# v 1 / 1
# end calcul
# time elapsed : 0.000159655
# non-strict_shortestfastest_passive 0.000159655
# 0<-
# results saved into files ?0 *0 means no, 1 yes*
# non-strict_shortestfastest_passive
# BFS version!
# looking until inf start time 1 end time 4
# REST = inf 1 4
# end calcul
# time elapsed : 4.6429e-05
# non-strict_shortestfastest_passive 4.6429e-05
# T 84
# n,T 9 84  nb edges 42 nTlog(nT) 5010.799280391727
# 0<-
# results saved into files ?0 *0 means no, 1 yes*
# non-strict_shortestfastest_passive
# Dijkstra version!
# pred has no loops speed up ? 0 *0 means no 1 means yes*
# v 0 / 8
# v 1 / 8
# v 2 / 8
# v 3 / 8
# v 4 / 8
# v 5 / 8
# v 6 / 8
# v 7 / 8
# v 8 / 8
# end calcul
# time elapsed : 0.00291164
# non-strict_shortestfastest_passive 0.00291164
# 0<-
# results saved into files ?0 *0 means no, 1 yes*
# non-strict_shortestfastest_passive
# Bellman-Ford version!
# pred has no loops speed up ? 0 *0 means no 1 means yes*
# v 0 / 8
# v 1 / 8
# v 2 / 8
# v 3 / 8
# v 4 / 8
# v 5 / 8
# v 6 / 8
# v 7 / 8
# v 8 / 8
# end calcul
# time elapsed : 0.0528426
# non-strict_shortestfastest_passive 0.0528426
# 0<-
# results saved into files ?0 *0 means no, 1 yes*
# non-strict_shortestfastest_passive
# BFS version!
# looking until inf start time 3 end time 84
# REST = inf 3 84
# end calcul
# time elapsed : 0.000214709
# non-strict_shortestfastest_passive 0.000214709
# T 164
# n,T 12 164  nb edges 58 nTlog(nT) 14926.833416740807
# 0<-
# results saved into files ?0 *0 means no, 1 yes*
# non-strict_shortestfastest_passive
# Dijkstra version!
# pred has no loops speed up ? 0 *0 means no 1 means yes*
# v 0 / 11
# v 1 / 11
# v 2 / 11
# v 3 / 11
# v 4 / 11
# v 5 / 11
# v 6 / 11
# v 7 / 11
# v 8 / 11
# v 9 / 11
# v 10 / 11
# v 11 / 11
# end calcul
# time elapsed : 0.00343242
# non-strict_shortestfastest_passive 0.00343242
# Graph read: 2 nodes, 4 (unique) directed edges, 4 (non-empty) timesteps
# Time for algorithms (in seconds):
# Graph read: 2 nodes, 4 (unique) directed edges, 4 (non-empty) timesteps
# Time for algorithms (in seconds):
# Graph read: 2 nodes, 4 (unique) directed edges, 4 (non-empty) timesteps
# Time for algorithms (in seconds):
# Graph read: 9 nodes, 42 (unique) directed edges, 35 (non-empty) timesteps
# Time for algorithms (in seconds):
# Graph read: 9 nodes, 42 (unique) directed edges, 35 (non-empty) timesteps
# Time for algorithms (in seconds):
# Graph read: 9 nodes, 42 (unique) directed edges, 35 (non-empty) timesteps
# Time for algorithms (in seconds):
# Graph read: 12 nodes, 58 (unique) directed edges, 48 (non-empty) timesteps
# Time for algorithms (in seconds):
# Graph read: 12 nodes, 58 (unique) directed edges, 48 (non-empty) timesteps
# Time for algorithms (in seconds):
# Graph read: 12 nodes, 58 (unique) directed edges, 48 (non-empty) timesteps
# Time for algorithms (in seconds):
# 0<-
# results saved into files ?0 *0 means no, 1 yes*
# non-strict_shortestfastest_passive
# Bellman-Ford version!
# pred has no loops speed up ? 0 *0 means no 1 means yes*
# v 0 / 11
# v 1 / 11
# v 2 / 11
# v 3 / 11
# v 4 / 11
# v 5 / 11
# v 6 / 11
# v 7 / 11
# v 8 / 11
# v 9 / 11
# v 10 / 11
# v 11 / 11
# end calcul
# time elapsed : 0.419111
# non-strict_shortestfastest_passive 0.419111
# 0<-
# results saved into files ?0 *0 means no, 1 yes*
# non-strict_shortestfastest_passive
# BFS version!
# looking until inf start time 1 end time 163
# REST = inf 1 163
# end calcul
# time elapsed : 0.000244647
# non-strict_shortestfastest_passive 0.000244647
# T 244
# n,T 15 244  nb edges 86 nTlog(nT) 30031.099440607206
# Graph read: 15 nodes, 86 (unique) directed edges, 71 (non-empty) timesteps
# Time for algorithms (in seconds):
# Graph read: 15 nodes, 86 (unique) directed edges, 71 (non-empty) timesteps
# 0<-
# results saved into files ?0 *0 means no, 1 yes*
# non-strict_shortestfastest_passive
# Dijkstra version!
# pred has no loops speed up ? 0 *0 means no 1 means yes*
# v 0 / 14
# v 1 / 14
# v 2 / 14
# v 3 / 14
# v 4 / 14
# v 5 / 14
# v 6 / 14
# v 7 / 14
# v 8 / 14
# v 9 / 14
# v 10 / 14
# v 11 / 14
# v 12 / 14
# v 13 / 14
# v 14 / 14
# end calcul
# time elapsed : 0.00853093
# non-strict_shortestfastest_passive 0.00853093
# Time for algorithms (in seconds):
# Graph read: 15 nodes, 86 (unique) directed edges, 71 (non-empty) timesteps
# Time for algorithms (in seconds):
# Graph read: 18 nodes, 76 (unique) directed edges, 72 (non-empty) timesteps
# Time for algorithms (in seconds):
# 0<-
# results saved into files ?0 *0 means no, 1 yes*
# non-strict_shortestfastest_passive
# Bellman-Ford version!
# pred has no loops speed up ? 0 *0 means no 1 means yes*
# v 0 / 14
# v 1 / 14
# v 2 / 14
# v 3 / 14
# v 4 / 14
# v 5 / 14
# v 6 / 14
# v 7 / 14
# v 8 / 14
# v 9 / 14
# v 10 / 14
# v 11 / 14
# v 12 / 14
# v 13 / 14
# v 14 / 14
# end calcul
# time elapsed : 2.58234
# non-strict_shortestfastest_passive 2.58234
# 0<-
# results saved into files ?0 *0 means no, 1 yes*
# non-strict_shortestfastest_passive
# BFS version!
# looking until inf start time 7 end time 234
# REST = inf 7 234
# end calcul
# time elapsed : 0.000580451
# non-strict_shortestfastest_passive 0.000580451
# T 324
# n,T 18 324  nb edges 76 nTlog(nT) 50569.9442761513
# 0<-
# results saved into files ?0 *0 means no, 1 yes*
# non-strict_shortestfastest_passive
# Dijkstra version!
# pred has no loops speed up ? 0 *0 means no 1 means yes*
# v 0 / 17
# v 1 / 17
# v 2 / 17
# v 3 / 17
# v 4 / 17
# v 5 / 17
# v 6 / 17
# v 7 / 17
# v 8 / 17
# v 9 / 17
# v 10 / 17
# v 11 / 17
# v 12 / 17
# v 13 / 17
# v 14 / 17
# v 15 / 17
# v 16 / 17
# v 17 / 17
# end calcul
# time elapsed : 0.00648362
# non-strict_shortestfastest_passive 0.00648362
# Graph read: 18 nodes, 76 (unique) directed edges, 72 (non-empty) timesteps
# 0<-
# results saved into files ?0 *0 means no, 1 yes*
# non-strict_shortestfastest_passive
# Bellman-Ford version!
# pred has no loops speed up ? 0 *0 means no 1 means yes*
# v 0 / 17
# v 1 / 17
# v 2 / 17
# v 3 / 17
# v 4 / 17
# v 5 / 17
# v 6 / 17
# v 7 / 17
# v 8 / 17
# v 9 / 17
# v 10 / 17
# v 11 / 17
# v 12 / 17
# v 13 / 17
# v 14 / 17
# v 15 / 17
# v 16 / 17
# v 17 / 17
# end calcul
# time elapsed : 3.23618
# non-strict_shortestfastest_passive 3.23618
# 0<-
# results saved into files ?0 *0 means no, 1 yes*
# non-strict_shortestfastest_passive
# BFS version!
# looking until inf start time 3 end time 312
# REST = inf 3 312
# end calcul
# time elapsed : 0.000454268
# non-strict_shortestfastest_passive 0.000454268
# T 404
# n,T 20 404
# Time for algorithms (in seconds):
# Graph read: 18 nodes, 76 (unique) directed edges, 72 (non-empty) timesteps
# Time for algorithms (in seconds):
# nb edges 93 nTlog(nT) 72696.94898424235
# 0<-
# results saved into files ?0 *0 means no, 1 yes*
# non-strict_shortestfastest_passive
# Dijkstra version!
# pred has no loops speed up ? 0 *0 means no 1 means yes*
# v 0 / 19
# v 1 / 19
# v 2 / 19
# v 3 / 19
# v 4 / 19
# v 5 / 19
# v 6 / 19
# v 7 / 19
# v 8 / 19
# v 9 / 19
# v 10 / 19
# v 11 / 19
# v 12 / 19
# v 13 / 19
# v 14 / 19
# v 15 / 19
# v 16 / 19
# v 17 / 19
# v 18 / 19
# v 19 / 19
# end calcul
# time elapsed : 0.00778715
# non-strict_shortestfastest_passive 0.00778715
# Graph read: 20 nodes, 93 (unique) directed edges, 84 (non-empty) timesteps
# Time for algorithms (in seconds):
# Graph read: 20 nodes, 93 (unique) directed edges, 84 (non-empty) timesteps
# 0<-
# results saved into files ?0 *0 means no, 1 yes*
# non-strict_shortestfastest_passive
# Bellman-Ford version!
# pred has no loops speed up ? 0 *0 means no 1 means yes*
# v 0 / 19
# v 1 / 19
# v 2 / 19
# v 3 / 19
# v 4 / 19
# v 5 / 19
# v 6 / 19
# v 7 / 19
# v 8 / 19
# v 9 / 19
# v 10 / 19
# v 11 / 19
# v 12 / 19
# v 13 / 19
# v 14 / 19
# v 15 / 19
# v 16 / 19
# v 17 / 19
# v 18 / 19
# v 19 / 19
# end calcul
# time elapsed : 7.12853
# non-strict_shortestfastest_passive 7.12853
# 0<-
# results saved into files ?0 *0 means no, 1 yes*
# non-strict_shortestfastest_passive
# BFS version!
# looking until inf start time 4 end time 401
# REST = inf 4 401
# end calcul
# time elapsed : 0.000524632
# non-strict_shortestfastest_passive 0.000524632
# T 484
# n,T 22 484
# Time for algorithms (in seconds):
# Graph read: 20 nodes, 93 (unique) directed edges, 84 (non-empty) timesteps
# Time for algorithms (in seconds):
# nb edges 104 nTlog(nT) 98740.26013007805
# 0<-
# results saved into files ?0 *0 means no, 1 yes*
# non-strict_shortestfastest_passive
# Dijkstra version!
# pred has no loops speed up ? 0 *0 means no 1 means yes*
# v 0 / 21
# v 1 / 21
# v 2 / 21
# v 3 / 21
# v 4 / 21
# v 5 / 21
# v 6 / 21
# v 7 / 21
# v 8 / 21
# v 9 / 21
# v 10 / 21
# v 11 / 21
# v 12 / 21
# v 13 / 21
# v 14 / 21
# v 15 / 21
# v 16 / 21
# v 17 / 21
# v 18 / 21
# v 19 / 21
# v 20 / 21
# v 21 / 21
# end calcul
# time elapsed : 0.0148504
# non-strict_shortestfastest_passive 0.0148504
# Graph read: 22 nodes, 104 (unique) directed edges, 96 (non-empty) timesteps
# Time for algorithms (in seconds):
# Graph read: 22 nodes, 104 (unique) directed edges, 96 (non-empty) timesteps
# 0<-
# results saved into files ?0 *0 means no, 1 yes*
# non-strict_shortestfastest_passive
# Bellman-Ford version!
# pred has no loops speed up ? 0 *0 means no 1 means yes*
# v 0 / 21
# v 1 / 21
# v 2 / 21
# v 3 / 21
# v 4 / 21
# v 5 / 21
# v 6 / 21
# v 7 / 21
# v 8 / 21
# v 9 / 21
# v 10 / 21
# v 11 / 21
# v 12 / 21
# v 13 / 21
# v 14 / 21
# v 15 / 21
# v 16 / 21
# v 17 / 21
# v 18 / 21
# v 19 / 21
# v 20 / 21
# v 21 / 21
# end calcul
# time elapsed : 11.4603
# non-strict_shortestfastest_passive 11.4603
# 0<-
# results saved into files ?0 *0 means no, 1 yes*
# non-strict_shortestfastest_passive
# BFS version!
# looking until inf start time 3 end time 482
# REST = inf 3 482
# end calcul
# time elapsed : 0.000729015
# non-strict_shortestfastest_passive 0.000729015
# T 564
# n,T 23 564
# Time for algorithms (in seconds):
# Graph read: 22 nodes, 104 (unique) directed edges, 96 (non-empty) timesteps
# Time for algorithms (in seconds):
# nb edges 95 nTlog(nT) 122851.95471946575
# 0<-
# results saved into files ?0 *0 means no, 1 yes*
# non-strict_shortestfastest_passive
# Dijkstra version!
# pred has no loops speed up ? 0 *0 means no 1 means yes*
# v 0 / 22
# v 1 / 22
# v 2 / 22
# v 3 / 22
# v 4 / 22
# v 5 / 22
# v 6 / 22
# v 7 / 22
# v 8 / 22
# v 9 / 22
# v 10 / 22
# v 11 / 22
# v 12 / 22
# v 13 / 22
# v 14 / 22
# v 15 / 22
# v 16 / 22
# v 17 / 22
# v 18 / 22
# v 19 / 22
# v 20 / 22
# v 21 / 22
# v 22 / 22
# end calcul
# time elapsed : 0.00913466
# non-strict_shortestfastest_passive 0.00913466
# Graph read: 23 nodes, 95 (unique) directed edges, 87 (non-empty) timesteps
# Time for algorithms (in seconds):
# Graph read: 23 nodes, 95 (unique) directed edges, 87 (non-empty) timesteps
# 0<-
# results saved into files ?0 *0 means no, 1 yes*
# non-strict_shortestfastest_passive
# Bellman-Ford version!
# pred has no loops speed up ? 0 *0 means no 1 means yes*
# v 0 / 22
# v 1 / 22
# v 2 / 22
# v 3 / 22
# v 4 / 22
# v 5 / 22
# v 6 / 22
# v 7 / 22
# v 8 / 22
# v 9 / 22
# v 10 / 22
# v 11 / 22
# v 12 / 22
# v 13 / 22
# v 14 / 22
# v 15 / 22
# v 16 / 22
# v 17 / 22
# v 18 / 22
# v 19 / 22
# v 20 / 22
# v 21 / 22
# v 22 / 22
# end calcul
# time elapsed : 8.78745
# non-strict_shortestfastest_passive 8.78745
# 0<-
# results saved into files ?0 *0 means no, 1 yes*
# non-strict_shortestfastest_passive
# BFS version!
# looking until inf start time 6 end time 561
# REST = inf 6 561
# end calcul
# time elapsed : 0.000520535
# non-strict_shortestfastest_passive 0.000520535
# Time for algorithms (in seconds):
# Graph read: 23 nodes, 95 (unique) directed edges, 87 (non-empty) timesteps
# Time for algorithms (in seconds):

# %%
import matplotlib.pyplot as plt 
labels = which
fig, ax = plt.subplots(layout='constrained')

for i in range(0,len(which),1):
    plt.plot(list(map(lambda x : x[0], l)), list(map(lambda x : x[1][i], l)), label = labels[i] )
for i in range(0,len(which)-1,1):
    plt.plot(list(map(lambda x : x[0], l2)), list(map(lambda x : x[1][i], l2)), label = labels[i] )

plt.legend()
ax.set_yscale('log')
ax.set_ylabel('Time in sec')
ax.set_xlabel('# time stamps')
plt.savefig('shf_t.png', dpi=300)
plt.show()
